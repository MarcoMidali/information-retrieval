# %% [markdown]
# # LOADING THE DATASET

# %%
# !sudo apt-get install python3.10
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.10 is already the newest version (3.10.12-1~22.04.7).
# python3.10 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 1

# %%
# !python --version
# Out:
# Python 3.11.11

# %%
# !pip install python-terrier
# !pip install --upgrade pytrec-eval-terrier
# !pip install ir-measures[cwl_eval]
# !pip install ir-measures[ranx]
# !pip install --upgrade git+https://github.com/Georgetown-IR-Lab/OpenNIR
# !pip install beir

import pyterrier as pt
import os
from google.colab import files
import onir_pt
# Out:
# Collecting python-terrier
#   Downloading python_terrier-0.13.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from python-terrier) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from python-terrier) (2.2.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from python-terrier) (10.5.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from python-terrier) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from python-terrier) (2.32.3)
# Collecting ir-datasets>=0.3.2 (from python-terrier)
#   Downloading ir_datasets-0.5.9-py3-none-any.whl.metadata (12 kB)
# Collecting wget (from python-terrier)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyjnius>=1.4.2 (from python-terrier)
#   Downloading pyjnius-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.11/dist-packages (from python-terrier) (1.2.15)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from python-terrier) (1.13.1)
# Collecting ir-measures>=0.3.1 (from python-terrier)
#   Downloading ir_measures-0.3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting pytrec-eval-terrier>=0.5.3 (from python-terrier)
#   Downloading pytrec_eval_terrier-0.5.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (777 bytes)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from python-terrier) (3.1.5)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (from python-terrier) (0.14.4)
# Collecting dill (from python-terrier)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from python-terrier) (1.4.2)
# Collecting chest (from python-terrier)
#   Downloading chest-0.2.3.tar.gz (9.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting lz4 (from python-terrier)
#   Downloading lz4-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (4.12.3)
# Collecting inscriptis>=2.2.0 (from ir-datasets>=0.3.2->python-terrier)
#   Downloading inscriptis-2.5.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (5.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (6.0.2)
# Collecting trec-car-tools>=2.5.4 (from ir-datasets>=0.3.2->python-terrier)
#   Downloading trec_car_tools-2.6-py3-none-any.whl.metadata (640 bytes)
# Collecting warc3-wet>=0.2.3 (from ir-datasets>=0.3.2->python-terrier)
#   Downloading warc3_wet-0.2.5-py3-none-any.whl.metadata (2.2 kB)
# Collecting warc3-wet-clueweb09>=0.2.5 (from ir-datasets>=0.3.2->python-terrier)
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting zlib-state>=0.1.3 (from ir-datasets>=0.3.2->python-terrier)
#   Downloading zlib_state-0.1.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting ijson>=3.1.3 (from ir-datasets>=0.3.2->python-terrier)
#   Downloading ijson-3.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting unlzw3>=0.2.1 (from ir-datasets>=0.3.2->python-terrier)
#   Downloading unlzw3-0.2.3-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier) (2024.12.14)
# Collecting heapdict (from chest->python-terrier)
#   Downloading HeapDict-1.0.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated->python-terrier) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->python-terrier) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->python-terrier) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->python-terrier) (2024.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels->python-terrier) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels->python-terrier) (24.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier) (2.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->python-terrier) (1.17.0)
# Collecting cbor>=1.0.0 (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier)
#   Downloading cbor-1.0.0.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Downloading python_terrier-0.13.0-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.4/163.4 kB 2.8 MB/s eta 0:00:00
# Downloading ir_datasets-0.5.9-py3-none-any.whl (347 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.9/347.9 kB 10.1 MB/s eta 0:00:00
# Downloading ir_measures-0.3.6-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 3.5 MB/s eta 0:00:00
# Downloading lz4-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.0 MB/s eta 0:00:00
# Downloading pyjnius-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.3 MB/s eta 0:00:00
# Downloading pytrec_eval_terrier-0.5.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.9/287.9 kB 8.7 MB/s eta 0:00:00
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 9.0 MB/s eta 0:00:00
# Downloading ijson-3.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.2/119.2 kB 7.2 MB/s eta 0:00:00
# Downloading inscriptis-2.5.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 2.4 MB/s eta 0:00:00
# Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Downloading unlzw3-0.2.3-py3-none-any.whl (6.7 kB)
# Downloading warc3_wet-0.2.5-py3-none-any.whl (18 kB)
# Downloading zlib_state-0.1.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Building wheels for collected packages: chest, wget, warc3-wet-clueweb09, cbor
#   Building wheel for chest (setup.py) ... done
#   Created wheel for chest: filename=chest-0.2.3-py3-none-any.whl size=7611 sha256=ecb2f6175c4a84144780d254944db3f47518c32dcc20c0b73ad9ee96c9d05572
#   Stored in directory: /root/.cache/pip/wheels/48/57/13/28831e81239278141f874ee9b7d6d5490a1b1191c2d07a3e73
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=43df96bea4e63608ba5d274a9765e66b6969885177fe80fd221c5acd49ded9cd
#   Stored in directory: /root/.cache/pip/wheels/40/b3/0f/a40dbd1c6861731779f62cc4babcb234387e11d697df70ee97
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18920 sha256=bab5faa899536045ab45dfca87fe3f246a2bf2308d83ecd5956a5c498b620237
#   Stored in directory: /root/.cache/pip/wheels/63/f9/dc/2dd16d3330e327236e4d407941975c42d5159d200cdb7922d8
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-cp311-cp311-linux_x86_64.whl size=53931 sha256=535ded66b5b6906ea71a7b09e29d070948956dbd5d10d187c059cdb25c898dca
#   Stored in directory: /root/.cache/pip/wheels/21/6b/45/0c34253b1af07d1d9dc524f6d44d74a6b191c43152e6aaf641
# Successfully built chest wget warc3-wet-clueweb09 cbor
# Installing collected packages: wget, warc3-wet-clueweb09, warc3-wet, pyjnius, ijson, heapdict, cbor, zlib-state, unlzw3, trec-car-tools, pytrec-eval-terrier, lz4, dill, chest, ir-measures, inscriptis, ir-datasets, python-terrier
# Successfully installed cbor-1.0.0 chest-0.2.3 dill-0.3.9 heapdict-1.0.1 ijson-3.3.0 inscriptis-2.5.3 ir-datasets-0.5.9 ir-measures-0.3.6 lz4-4.3.3 pyjnius-1.6.1 python-terrier-0.13.0 pytrec-eval-terrier-0.5.6 trec-car-tools-2.6 unlzw3-0.2.3 warc3-wet-0.2.5 warc3-wet-clueweb09-0.2.5 wget-3.2 zlib-state-0.1.9
# Requirement already satisfied: pytrec-eval-terrier in /usr/local/lib/python3.11/dist-packages (0.5.6)
# Requirement already satisfied: ir-measures[cwl_eval] in /usr/local/lib/python3.11/dist-packages (0.3.6)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.5 in /usr/local/lib/python3.11/dist-packages (from ir-measures[cwl_eval]) (0.5.6)
# Collecting cwl-eval>=1.0.10 (from ir-measures[cwl_eval])
#   Downloading cwl-eval-1.0.12.tar.gz (31 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from cwl-eval>=1.0.10->ir-measures[cwl_eval]) (1.26.4)
# Building wheels for collected packages: cwl-eval
#   Building wheel for cwl-eval (setup.py) ... done
#   Created wheel for cwl-eval: filename=cwl_eval-1.0.12-py3-none-any.whl size=38068 sha256=65fd7a27ea207e2bc8407c42ddbdaccb7de107fd72cd8920b9eeb5f1d1840b48
#   Stored in directory: /root/.cache/pip/wheels/69/b2/12/4e7d9dce1cd0d65b194a3284751974094d020da593d750e76a
# Successfully built cwl-eval
# Installing collected packages: cwl-eval
# Successfully installed cwl-eval-1.0.12
# Requirement already satisfied: ir-measures[ranx] in /usr/local/lib/python3.11/dist-packages (0.3.6)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.5 in /usr/local/lib/python3.11/dist-packages (from ir-measures[ranx]) (0.5.6)
# Collecting ranx>=0.1.11 (from ir-measures[ranx])
#   Downloading ranx-0.3.20-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ranx>=0.1.11->ir-measures[ranx]) (1.26.4)
# Requirement already satisfied: numba>=0.54.1 in /usr/local/lib/python3.11/dist-packages (from ranx>=0.1.11->ir-measures[ranx]) (0.60.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from ranx>=0.1.11->ir-measures[ranx]) (2.2.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from ranx>=0.1.11->ir-measures[ranx]) (0.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from ranx>=0.1.11->ir-measures[ranx]) (4.67.1)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ranx>=0.1.11->ir-measures[ranx]) (1.13.1)
# Requirement already satisfied: ir-datasets in /usr/local/lib/python3.11/dist-packages (from ranx>=0.1.11->ir-measures[ranx]) (0.5.9)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from ranx>=0.1.11->ir-measures[ranx]) (13.9.4)
# Requirement already satisfied: orjson in /usr/local/lib/python3.11/dist-packages (from ranx>=0.1.11->ir-measures[ranx]) (3.10.14)
# Requirement already satisfied: lz4 in /usr/local/lib/python3.11/dist-packages (from ranx>=0.1.11->ir-measures[ranx]) (4.3.3)
# Collecting cbor2 (from ranx>=0.1.11->ir-measures[ranx])
#   Downloading cbor2-5.6.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.0 kB)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from ranx>=0.1.11->ir-measures[ranx]) (0.13.2)
# Collecting fastparquet (from ranx>=0.1.11->ir-measures[ranx])
#   Downloading fastparquet-2024.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54.1->ranx>=0.1.11->ir-measures[ranx]) (0.43.0)
# Collecting cramjam>=2.3 (from fastparquet->ranx>=0.1.11->ir-measures[ranx])
#   Downloading cramjam-2.9.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from fastparquet->ranx>=0.1.11->ir-measures[ranx]) (2024.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from fastparquet->ranx>=0.1.11->ir-measures[ranx]) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->ranx>=0.1.11->ir-measures[ranx]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->ranx>=0.1.11->ir-measures[ranx]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->ranx>=0.1.11->ir-measures[ranx]) (2024.2)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from ir-datasets->ranx>=0.1.11->ir-measures[ranx]) (4.12.3)
# Requirement already satisfied: inscriptis>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from ir-datasets->ranx>=0.1.11->ir-measures[ranx]) (2.5.3)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.11/dist-packages (from ir-datasets->ranx>=0.1.11->ir-measures[ranx]) (5.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ir-datasets->ranx>=0.1.11->ir-measures[ranx]) (6.0.2)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.11/dist-packages (from ir-datasets->ranx>=0.1.11->ir-measures[ranx]) (2.32.3)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.11/dist-packages (from ir-datasets->ranx>=0.1.11->ir-measures[ranx]) (2.6)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from ir-datasets->ranx>=0.1.11->ir-measures[ranx]) (0.2.5)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.11/dist-packages (from ir-datasets->ranx>=0.1.11->ir-measures[ranx]) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from ir-datasets->ranx>=0.1.11->ir-measures[ranx]) (0.1.9)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.11/dist-packages (from ir-datasets->ranx>=0.1.11->ir-measures[ranx]) (3.3.0)
# Requirement already satisfied: unlzw3>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from ir-datasets->ranx>=0.1.11->ir-measures[ranx]) (0.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->ranx>=0.1.11->ir-measures[ranx]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->ranx>=0.1.11->ir-measures[ranx]) (2.18.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn->ranx>=0.1.11->ir-measures[ranx]) (3.10.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets->ranx>=0.1.11->ir-measures[ranx]) (2.6)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->ranx>=0.1.11->ir-measures[ranx]) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx>=0.1.11->ir-measures[ranx]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx>=0.1.11->ir-measures[ranx]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx>=0.1.11->ir-measures[ranx]) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx>=0.1.11->ir-measures[ranx]) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx>=0.1.11->ir-measures[ranx]) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn->ranx>=0.1.11->ir-measures[ranx]) (3.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->ranx>=0.1.11->ir-measures[ranx]) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->ir-datasets->ranx>=0.1.11->ir-measures[ranx]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->ir-datasets->ranx>=0.1.11->ir-measures[ranx]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->ir-datasets->ranx>=0.1.11->ir-measures[ranx]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->ir-datasets->ranx>=0.1.11->ir-measures[ranx]) (2024.12.14)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from trec-car-tools>=2.5.4->ir-datasets->ranx>=0.1.11->ir-measures[ranx]) (1.0.0)
# Downloading ranx-0.3.20-py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.3/99.3 kB 3.6 MB/s eta 0:00:00
# Downloading cbor2-5.6.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.2/249.2 kB 10.7 MB/s eta 0:00:00
# Downloading fastparquet-2024.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 35.0 MB/s eta 0:00:00
# Downloading cramjam-2.9.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 60.6 MB/s eta 0:00:00
# Installing collected packages: cramjam, cbor2, fastparquet, ranx
# Successfully installed cbor2-5.6.5 cramjam-2.9.1 fastparquet-2024.11.0 ranx-0.3.20
# Collecting git+https://github.com/Georgetown-IR-Lab/OpenNIR
#   Cloning https://github.com/Georgetown-IR-Lab/OpenNIR to /tmp/pip-req-build-quoydfdm
#   Running command git clone --filter=blob:none --quiet https://github.com/Georgetown-IR-Lab/OpenNIR /tmp/pip-req-build-quoydfdm
#   Resolved https://github.com/Georgetown-IR-Lab/OpenNIR to commit c1f71d2af4de162f8b7c464df4b88fb5f4b4b45d
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from OpenNIR==0.1.0) (2.5.1+cu121)
# Collecting pytorch-pretrained-bert==0.6.1 (from OpenNIR==0.1.0)
#   Downloading pytorch_pretrained_bert-0.6.1-py3-none-any.whl.metadata (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.7/74.7 kB 2.0 MB/s eta 0:00:00
# Collecting pytorch-transformers==1.1.0 (from OpenNIR==0.1.0)
#   Downloading pytorch_transformers-1.1.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tokenizers>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from OpenNIR==0.1.0) (0.21.0)
# Requirement already satisfied: transformers>=4.3.3 in /usr/local/lib/python3.11/dist-packages (from OpenNIR==0.1.0) (4.47.1)
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from OpenNIR==0.1.0) (4.67.1)
# Collecting colorlog==4.0.2 (from OpenNIR==0.1.0)
#   Downloading colorlog-4.0.2-py2.py3-none-any.whl.metadata (9.4 kB)
# Collecting terminaltables>=3.1.0 (from OpenNIR==0.1.0)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: matplotlib>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from OpenNIR==0.1.0) (3.10.0)
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from OpenNIR==0.1.0) (0.13.2)
# Collecting python-ternary>=1.0.6 (from OpenNIR==0.1.0)
#   Downloading python_ternary-1.0.8-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: beautifulsoup4>=4.9.3 in /usr/local/lib/python3.11/dist-packages (from OpenNIR==0.1.0) (4.12.3)
# Requirement already satisfied: html5lib>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from OpenNIR==0.1.0) (1.1)
# Collecting Unidecode>=1.0.22 (from OpenNIR==0.1.0)
#   Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: nltk>=3.4.5 in /usr/local/lib/python3.11/dist-packages (from OpenNIR==0.1.0) (3.9.1)
# Collecting sqlitedict>=1.6.0 (from OpenNIR==0.1.0)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pytrec-eval-terrier>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from OpenNIR==0.1.0) (0.5.6)
# Requirement already satisfied: gensim>=3.7.3 in /usr/local/lib/python3.11/dist-packages (from OpenNIR==0.1.0) (4.3.3)
# Requirement already satisfied: Cython>=0.29.2 in /usr/local/lib/python3.11/dist-packages (from OpenNIR==0.1.0) (3.0.11)
# Requirement already satisfied: pyjnius>=1.2.1 in /usr/local/lib/python3.11/dist-packages (from OpenNIR==0.1.0) (1.6.1)
# Requirement already satisfied: ir_datasets>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from OpenNIR==0.1.0) (0.5.9)
# Requirement already satisfied: ir_measures>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from OpenNIR==0.1.0) (0.3.6)
# Collecting pytools>=2018.5.2 (from OpenNIR==0.1.0)
#   Downloading pytools-2025.1.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting cached-property>=1.5.1 (from OpenNIR==0.1.0)
#   Downloading cached_property-2.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (1.26.4)
# Collecting boto3 (from pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0)
#   Downloading boto3-1.36.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (2.32.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (2024.11.6)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from pytorch-transformers==1.1.0->OpenNIR==0.1.0) (0.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.9.3->OpenNIR==0.1.0) (2.6)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from gensim>=3.7.3->OpenNIR==0.1.0) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim>=3.7.3->OpenNIR==0.1.0) (7.1.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.11/dist-packages (from html5lib>=1.0.1->OpenNIR==0.1.0) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from html5lib>=1.0.1->OpenNIR==0.1.0) (0.5.1)
# Requirement already satisfied: inscriptis>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (2.5.3)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.11/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (5.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (6.0.2)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.11/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in /usr/local/lib/python3.11/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (4.3.3)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.2.5)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.11/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.1.9)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.11/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (3.3.0)
# Requirement already satisfied: unlzw3>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from ir_datasets>=0.2.0->OpenNIR==0.1.0) (0.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.2->OpenNIR==0.1.0) (2.8.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.4.5->OpenNIR==0.1.0) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.4.5->OpenNIR==0.1.0) (1.4.2)
# Requirement already satisfied: platformdirs>=2.2 in /usr/local/lib/python3.11/dist-packages (from pytools>=2018.5.2->OpenNIR==0.1.0) (4.3.6)
# Requirement already satisfied: typing-extensions>=4.5 in /usr/local/lib/python3.11/dist-packages (from pytools>=2018.5.2->OpenNIR==0.1.0) (4.12.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn>=0.9.0->OpenNIR==0.1.0) (2.2.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.1.1->OpenNIR==0.1.0) (0.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3.1->OpenNIR==0.1.0) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.3.1->OpenNIR==0.1.0) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.3.1->OpenNIR==0.1.0) (1.3.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.3.3->OpenNIR==0.1.0) (0.5.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn>=0.9.0->OpenNIR==0.1.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn>=0.9.0->OpenNIR==0.1.0) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0) (2024.12.14)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim>=3.7.3->OpenNIR==0.1.0) (1.17.0)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from trec-car-tools>=2.5.4->ir_datasets>=0.2.0->OpenNIR==0.1.0) (1.0.0)
# Collecting botocore<1.37.0,>=1.36.4 (from boto3->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0)
#   Downloading botocore-1.36.4-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.12.0,>=0.11.0 (from boto3->pytorch-pretrained-bert==0.6.1->OpenNIR==0.1.0)
#   Downloading s3transfer-0.11.1-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3.1->OpenNIR==0.1.0) (3.0.2)
# Downloading colorlog-4.0.2-py2.py3-none-any.whl (17 kB)
# Downloading pytorch_pretrained_bert-0.6.1-py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.3/114.3 kB 4.4 MB/s eta 0:00:00
# Downloading pytorch_transformers-1.1.0-py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.1/158.1 kB 11.6 MB/s eta 0:00:00
# Downloading cached_property-2.0.1-py3-none-any.whl (7.4 kB)
# Downloading python_ternary-1.0.8-py3-none-any.whl (18 kB)
# Downloading pytools-2025.1.1-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.8/92.8 kB 4.0 MB/s eta 0:00:00
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 14.3 MB/s eta 0:00:00
# Downloading boto3-1.36.4-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 9.8 MB/s eta 0:00:00
# Downloading botocore-1.36.4-py3-none-any.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 9.3 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.11.1-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 6.5 MB/s eta 0:00:00
# Building wheels for collected packages: OpenNIR, sqlitedict
#   Building wheel for OpenNIR (setup.py) ... done
#   Created wheel for OpenNIR: filename=OpenNIR-0.1.0-py3-none-any.whl size=55851460 sha256=198d34e38b52da99fb1a2ffcd182f7d919aa2e96ddae81d9a5bd5292c2a526cc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-myq2iy96/wheels/78/85/1c/5dd26dc445e17937d3c9d79944f07a40a568fb91dc1fd68842
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16864 sha256=95909de511083050bf1ce5588441bf6d12748ae45edd7a08cdb8a2532a21d190
#   Stored in directory: /root/.cache/pip/wheels/73/63/89/7210274f9b7fb033b8f22671f64c0e0b55083d30c3c046a3ff
# Successfully built OpenNIR sqlitedict
# Installing collected packages: sqlitedict, colorlog, Unidecode, terminaltables, pytools, jmespath, cached-property, botocore, s3transfer, python-ternary, boto3, pytorch-transformers, pytorch-pretrained-bert, OpenNIR
# Successfully installed OpenNIR-0.1.0 Unidecode-1.3.8 boto3-1.36.4 botocore-1.36.4 cached-property-2.0.1 colorlog-4.0.2 jmespath-1.0.1 python-ternary-1.0.8 pytools-2025.1.1 pytorch-pretrained-bert-0.6.1 pytorch-transformers-1.1.0 s3transfer-0.11.1 sqlitedict-2.1.0 terminaltables-3.1.10
# Collecting beir
#   Downloading beir-2.0.0.tar.gz (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (from beir) (3.3.1)
# Collecting pytrec_eval (from beir)
#   Downloading pytrec_eval-0.5.tar.gz (15 kB)
#   Preparing metadata (setup.py) ... done
# Collecting faiss_cpu (from beir)
#   Downloading faiss_cpu-1.9.0.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Collecting elasticsearch==7.9.1 (from beir)
#   Downloading elasticsearch-7.9.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting datasets (from beir)
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from elasticsearch==7.9.1->beir) (2.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from elasticsearch==7.9.1->beir) (2024.12.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets->beir) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets->beir) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets->beir) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->beir)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets->beir) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets->beir) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets->beir) (4.67.1)
# Collecting xxhash (from datasets->beir)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets->beir)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets->beir)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets->beir) (3.11.11)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from datasets->beir) (0.27.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets->beir) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets->beir) (6.0.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers->beir) (4.47.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers->beir) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers->beir) (1.6.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers->beir) (1.13.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers->beir) (11.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->beir) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->beir) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->beir) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->beir) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->beir) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->beir) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets->beir) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23.0->datasets->beir) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets->beir) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets->beir) (3.10)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->beir) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers->beir) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers->beir) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->beir) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->beir) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->beir) (0.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->beir) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->beir) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->beir) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers->beir) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers->beir) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->beir) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers->beir) (3.0.2)
# Downloading elasticsearch-7.9.1-py2.py3-none-any.whl (219 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.2/219.2 kB 5.9 MB/s eta 0:00:00
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 18.8 MB/s eta 0:00:00
# Downloading faiss_cpu-1.9.0.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 32.4 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.3 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 13.7 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.5 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 15.9 MB/s eta 0:00:00
# Building wheels for collected packages: beir, pytrec_eval
#   Building wheel for beir (setup.py) ... done
#   Created wheel for beir: filename=beir-2.0.0-py3-none-any.whl size=63550 sha256=76cb6c81a9554a2f27e234f0baacc549cf37ebca0974a322d3f62a89c48df23e
#   Stored in directory: /root/.cache/pip/wheels/87/4d/5d/5b20c57488e83fc5dab7a9a3442c0555b6c4094d1504a22ac3
#   Building wheel for pytrec_eval (setup.py) ... done
#   Created wheel for pytrec_eval: filename=pytrec_eval-0.5-cp311-cp311-linux_x86_64.whl size=308666 sha256=db3a59e1e3089463b4d539d4b6f0f30c24e2878558dd50ae8b32b767a82267af
#   Stored in directory: /root/.cache/pip/wheels/0f/89/42/86aecdb99975f1840c27bc37fdfed72116abcf82e2c9dc76a8
# Successfully built beir pytrec_eval
# Installing collected packages: xxhash, pytrec_eval, fsspec, faiss_cpu, elasticsearch, dill, multiprocess, datasets, beir
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.9
#     Uninstalling dill-0.3.9:
#       Successfully uninstalled dill-0.3.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed beir-2.0.0 datasets-3.2.0 dill-0.3.8 elasticsearch-7.9.1 faiss_cpu-1.9.0.post1 fsspec-2024.9.0 multiprocess-0.70.16 pytrec_eval-0.5 xxhash-3.5.0
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.

# %%
from beir import util, LoggingHandler
from beir.retrieval import models
from beir.datasets.data_loader import GenericDataLoader
from beir.retrieval.evaluation import EvaluateRetrieval
from beir.retrieval.search.dense import DenseRetrievalExactSearch as DRES

import logging
import pathlib, os

#### Just some code to print debug information to stdout
logging.basicConfig(format='%(asctime)s - %(message)s',
                    datefmt='%Y-%m-%d %H:%M:%S',
                    level=logging.INFO,
                    handlers=[LoggingHandler()])
#### /print debug information to stdout

#### Download NFCorpus.zip dataset and unzip the dataset
dataset = "nfcorpus"
url = "https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/{}.zip".format(dataset)
out_dir = os.path.join(pathlib.Path('./').parent.absolute(), "datasets")
data_path = util.download_and_unzip(url, out_dir)

#### Provide the data_path where NFCorpus has been downloaded and unzipped
corpus, queries, qrels = GenericDataLoader(data_folder=data_path).load(split="test")
# Out:
# /content/datasets/nfcorpus.zip:   0%|          | 0.00/2.34M s<?, ?iB/s]
#   0%|          | 0/3633 s<?, ?it/s]

# %%
import pandas as pd
data = pd.DataFrame.from_dict(corpus, orient='index')
data['doc_id'] = data.index
data.reset_index(drop=True, inplace=True)
data.head()
# Out:
#                                                 text  \
# 0  Recent studies have suggested that statins, an...
# 1  BACKGROUND: Preclinical studies have shown tha...
# 2  The aims of this study were to determine the c...
# 3  Epilepsy or seizure disorder is one of the mos...
# 4  Hit Reaction Time latencies (HRT) in the Conti...
#
#                                                title   doc_id
# 0  Statin Use and Breast Cancer Survival: A Natio...   MED-10
# 1  Statin use after diagnosis of breast cancer an...   MED-14
# 2  Alkylphenols in human milk and their relations...  MED-118
# 3  Methylmercury: A Potential Environmental Risk ...  MED-301
# 4  Sensitivity of Continuous Performance Test (CP...  MED-306

# %%
queries = pd.DataFrame.from_dict(queries, orient='index', columns=['query_text'])
queries['query_id'] = queries.index
queries.reset_index(drop=True, inplace=True)
queries.head()
# Out:
#                                           query_text  query_id
# 0   Do Cholesterol Statin Drugs Cause Breast Cancer?   PLAIN-2
# 1                Exploiting Autophagy to Live Longer  PLAIN-12
# 2  How to Reduce Exposure to Alkylphenols Through...  PLAIN-23
# 3          What’s Driving America’s Obesity Problem?  PLAIN-33
# 4              Who Should be Careful About Curcumin?  PLAIN-44

# %%
flat_qrels = [{'query_id': query_id, 'doc_id': doc_id, 'relevance': relevance}
              for query_id, inner_dict in qrels.items()
              for doc_id, relevance in inner_dict.items()]

qrels_df = pd.DataFrame(flat_qrels)
qrels_df.sample(20)
# Out:
#          query_id    doc_id  relevance
# 12266  PLAIN-3462  MED-5273          2
# 8586   PLAIN-2061  MED-1280          1
# 5615   PLAIN-1527  MED-2616          1
# 11201  PLAIN-2800  MED-4454          1
# 11772  PLAIN-3271  MED-1613          1
# 7329   PLAIN-1837  MED-5339          1
# 1545    PLAIN-531  MED-2279          1
# 4937   PLAIN-1419  MED-3281          1
# 8870   PLAIN-2061  MED-4738          1
# 8362   PLAIN-2051  MED-2008          1
# 10499  PLAIN-2610  MED-2644          1
# 12178  PLAIN-3432  MED-3464          1
# 518     PLAIN-112  MED-4490          1
# 12313  PLAIN-3462  MED-2382          1
# 6928   PLAIN-1741  MED-4345          1
# 9857   PLAIN-2430  MED-2669          1
# 8718   PLAIN-2061  MED-3022          1
# 7623   PLAIN-1909  MED-2847          1
# 6101   PLAIN-1635  MED-3227          1
# 5382   PLAIN-1453  MED-5056          1

# %% [markdown]
# # ADJUSTING THE DATASETS

# %% [markdown]
# ## DATA

# %%
#Adjust the corpus in the rigth format
data.rename(columns={'doc_id': 'docno'}, inplace=True)
data = data[['docno', 'title', 'text']]

# %% [markdown]
# ## QUERIES

# %%
#Firstly, we have to rename the columns of the queries
queries.rename(columns={'query_id': 'qid', 'query_text': 'query'}, inplace=True)

#Secondly, we have to follow this order in the columns: ['qid', 'query']
queries = queries[['qid', 'query']]

#Thirdly we remove special characters that could disturb the query parser
queries['query'] = queries['query'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)

# %% [markdown]
# ## QRLES

# %%
qrels_df.rename(columns={'query_id': 'qid', 'doc_id': 'docno', 'relevance': 'label'}, inplace=True)

# %%
#Create a function for adjusting the inconsistences between the ranking and the qrles

def adjust_qrels(results_pipeline, qrels_df):

  #We take the unique qid of the queries present in the ranking and in the qrles dataset
  qrels_queries = set(qrels_df['qid'].unique())
  run_queries = set(results_pipeline['qid'].unique())

  #We obtain the qid of the queries present in the qrles dataset but not in the ranking
  missing_in_run = qrels_queries - run_queries

  #We create a dataset for these queries. Each query will be associated with a fake document named "dummy" and will produce a score of zero.
  empty_results = pd.DataFrame({'qid': list(missing_in_run), 'docno': ['dummy'] * len(missing_in_run), 'score': [0] * len(missing_in_run)})

  # We combine the ranking with the new dataset we have just created
  results_pipeline = pd.concat([results_pipeline, empty_results])

  # We control that the query present in the ranking are also present in the qrles
  results_pipeline = results_pipeline[results_pipeline['qid'].isin(qrels_queries)]

  return results_pipeline

# %% [markdown]
# # Data Analysis

# %%
total_terms = {doc_id: len(doc.split()) for doc_id, doc in data['text'].items()}

# %%
total_terms_df = pd.DataFrame.from_dict(total_terms, orient = 'index', columns = ['total_terms'])
round(total_terms_df['total_terms'].mean())
#  382: 266,
#  383: 253,
#  384: 210,
#  385: 228,
#  386: 171,
#  387: 333,
#  388: 196,
#  389: 199,
#  390: 161,
#  391: 208,
#  392: 216,
#  393: 112,
#  394: 137,
#  395: 253,
#  396: 239,
#  397: 266,
#  398: 205,
#  399: 267,
#  400: 164,
#  401: 258,
#  402: 233,
#  403: 262,
#  404: 345,
#  405: 119,
#  406: 162,
#  407: 184,
#  408: 156,
#  409: 241,
#  410: 174,
#  411: 136,
#  412: 159,
#  413: 207,
#  414: 204,
#  415: 203,
#  416: 143,
#  417: 94,
#  418: 192,
#  419: 379,
#  420: 207,
#  421: 228,
#  422: 65,
#  423: 99,
#  424: 77,
#  425: 235,
#  426: 50,
#  427: 200,
#  428: 236,
#  429: 225,
#  430: 127,
#  431: 135,
#  432: 90,
#  433: 278,
#  434: 205,
#  435: 212,
#  436: 264,
#  437: 183,
#  438: 152,
#  439: 173,
#  440: 251,
#  441: 249,
#  442: 167,
#  443: 182,
#  444: 256,
#  445: 133,
#  446: 144,
#  447: 178,
#  448: 262,
#  449: 191,
#  450: 266,
#  451: 254,
#  452: 197,
#  453: 331,
#  454: 286,
#  455: 270,
#  456: 276,
#  457: 148,
#  458: 317,
#  459: 258,
#  460: 361,
#  461: 175,
#  462: 210,
#  463: 216,
#  464: 296,
#  465: 256,
#  466: 200,
#  467: 248,
#  468: 260,
#  469: 337,
#  470: 281,
#  471: 299,
#  472: 315,
#  473: 289,
#  474: 304,
#  475: 250,
#  476: 74,
#  477: 126,
#  478: 984,
#  479: 157,
#  480: 299,
#  481: 265,
#  482: 278,
#  483: 149,
#  484: 289,
#  485: 167,
#  486: 238,
#  487: 291,
#  488: 65,
#  489: 203,
#  490: 266,
#  491: 214,
#  492: 217,
#  493: 249,
#  494: 127,
#  495: 238,
#  496: 211,
#  497: 108,
#  498: 258,
#  499: 272,
#  500: 303,
#  501: 206,
#  502: 306,
#  503: 201,
#  504: 256,
#  505: 183,
#  506: 293,
#  507: 249,
#  508: 280,
#  509: 360,
#  510: 263,
#  511: 297,
#  512: 220,
#  513: 301,
#  514: 179,
#  515: 346,
#  516: 265,
#  517: 254,
#  518: 269,
#  519: 257,
#  520: 215,
#  521: 316,
#  522: 264,
#  523: 222,
#  524: 266,
#  525: 309,
#  526: 227,
#  527: 285,
#  528: 134,
#  529: 247,
#  530: 64,
#  531: 215,
#  532: 119,
#  533: 268,
#  534: 218,
#  535: 252,
#  536: 218,
#  537: 248,
#  538: 207,
#  539: 218,
#  540: 90,
#  541: 181,
#  542: 204,
#  543: 277,
#  544: 127,
#  545: 203,
#  546: 204,
#  547: 256,
#  548: 179,
#  549: 117,
#  550: 198,
#  551: 220,
#  552: 215,
#  553: 283,
#  554: 171,
#  555: 181,
#  556: 159,
#  557: 228,
#  558: 243,
#  559: 230,
#  560: 139,
#  561: 104,
#  562: 239,
#  563: 139,
#  564: 302,
#  565: 181,
#  566: 283,
#  567: 201,
#  568: 246,
#  569: 90,
#  570: 149,
#  571: 263,
#  572: 236,
#  573: 235,
#  574: 333,
#  767: 247,
#  768: 163,
#  769: 184,
#  770: 237,
#  771: 203,
#  772: 243,
#  773: 164,
#  774: 202,
#  775: 211,
#  776: 201,
#  777: 182,
#  778: 244,
#  779: 249,
#  780: 123,
#  781: 277,
#  782: 148,
#  783: 249,
#  784: 239,
#  785: 75,
#  786: 250,
#  787: 244,
#  788: 141,
#  789: 285,
#  790: 222,
#  791: 277,
#  792: 297,
#  793: 208,
#  794: 202,
#  795: 300,
#  796: 183,
#  797: 102,
#  798: 238,
#  799: 328,
#  800: 259,
#  801: 198,
#  802: 268,
#  803: 143,
#  804: 198,
#  805: 198,
#  806: 411,
#  807: 176,
#  808: 117,
#  809: 206,
#  810: 173,
#  811: 276,
#  812: 295,
#  813: 242,
#  814: 250,
#  815: 239,
#  816: 189,
#  817: 173,
#  818: 99,
#  819: 193,
#  820: 157,
#  821: 187,
#  822: 162,
#  823: 157,
#  824: 245,
#  825: 149,
#  826: 173,
#  827: 87,
#  828: 190,
#  829: 245,
#  830: 254,
#  831: 293,
#  832: 239,
#  833: 309,
#  834: 223,
#  835: 216,
#  836: 197,
#  837: 267,
#  838: 133,
#  839: 160,
#  840: 186,
#  841: 57,
#  842: 415,
#  843: 291,
#  844: 217,
#  845: 265,
#  846: 191,
#  847: 205,
#  848: 229,
#  849: 248,
#  850: 253,
#  851: 192,
#  852: 201,
#  853: 176,
#  854: 217,
#  855: 209,
#  856: 213,
#  857: 284,
#  858: 197,
#  859: 115,
#  860: 281,
#  861: 253,
#  862: 160,
#  863: 304,
#  864: 316,
#  865: 310,
#  866: 203,
#  867: 221,
#  868: 212,
#  869: 275,
#  870: 270,
#  871: 300,
#  872: 159,
#  873: 150,
#  874: 263,
#  875: 290,
#  876: 179,
#  877: 297,
#  878: 237,
#  879: 289,
#  880: 258,
#  881: 200,
#  882: 238,
#  883: 259,
#  884: 220,
#  885: 309,
#  886: 304,
#  887: 226,
#  888: 249,
#  889: 265,
#  890: 250,
#  891: 231,
#  892: 237,
#  893: 276,
#  894: 250,
#  895: 316,
#  896: 141,
#  897: 226,
#  898: 323,
#  899: 169,
#  900: 244,
#  901: 121,
#  902: 264,
#  903: 222,
#  904: 195,
#  905: 128,
#  906: 363,
#  907: 173,
#  908: 339,
#  909: 245,
#  910: 169,
#  911: 253,
#  912: 77,
#  913: 268,
#  914: 250,
#  915: 220,
#  916: 171,
#  917: 228,
#  918: 248,
#  919: 322,
#  920: 384,
#  921: 411,
#  922: 256,
#  923: 132,
#  924: 231,
#  925: 189,
#  926: 249,
#  927: 267,
#  928: 386,
#  929: 264,
#  930: 250,
#  931: 278,
#  932: 202,
#  933: 301,
#  934: 242,
#  935: 250,
#  936: 257,
#  937: 223,
#  938: 193,
#  939: 249,
#  940: 198,
#  941: 283,
#  942: 294,
#  943: 238,
#  944: 116,
#  945: 207,
#  946: 246,
#  947: 290,
#  948: 391,
#  949: 248,
#  950: 234,
#  951: 274,
#  952: 202,
#  953: 242,
#  954: 248,
#  955: 328,
#  956: 198,
#  957: 231,
#  958: 234,
#  959: 220,
#  960: 254,
#  961: 143,
#  962: 200,
#  963: 280,
#  964: 236,
#  965: 199,
#  966: 369,
#  967: 168,
#  968: 138,
#  969: 226,
#  970: 134,
#  971: 198,
#  972: 182,
#  973: 277,
#  974: 210,
#  975: 108,
#  976: 104,
#  977: 168,
#  978: 283,
#  979: 167,
#  980: 127,
#  981: 246,
#  982: 258,
#  983: 168,
#  984: 94,
#  985: 109,
#  986: 155,
#  987: 155,
#  988: 255,
#  989: 299,
#  990: 347,
#  991: 192,
#  992: 191,
#  993: 177,
#  994: 47,
#  995: 259,
#  996: 218,
#  997: 299,
#  998: 567,
#  999: 198,
#  ...}

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from collections import Counter
import matplotlib.pyplot as plt

# %%
stemmer = PorterStemmer()

# %%
total_terms_stem = {}
for doc_id, doc in data['text'].items():
  tokens = [stemmer.stem(word) for word in doc.lower().split() if word not in tokens]
  total_terms_stem[doc_id] = len(tokens)

# %%
total_terms_stem_df = pd.DataFrame.from_dict(total_terms_stem, orient = 'index', columns = ['total_terms_stem'])
round(total_terms_stem_df['total_terms_stem'].mean())
# Out:
# 185

# %%
total_terms_stem
# Out:
# {0: 219,
#  1: 162,
#  2: 160,
#  3: 156,
#  4: 234,
#  5: 204,
#  6: 153,
#  7: 212,
#  8: 230,
#  9: 166,
#  10: 121,
#  11: 184,
#  12: 184,
#  13: 151,
#  14: 145,
#  15: 228,
#  16: 189,
#  17: 232,
#  18: 140,
#  19: 160,
#  20: 241,
#  21: 209,
#  22: 109,
#  23: 207,
#  24: 142,
#  25: 299,
#  26: 199,
#  27: 104,
#  28: 151,
#  29: 166,
#  30: 51,
#  31: 197,
#  32: 102,
#  33: 200,
#  34: 209,
#  35: 185,
#  36: 186,
#  37: 241,
#  38: 107,
#  39: 84,
#  40: 99,
#  41: 145,
#  42: 186,
#  43: 216,
#  44: 232,
#  45: 152,
#  46: 188,
#  47: 118,
#  48: 112,
#  49: 108,
#  50: 237,
#  51: 246,
#  52: 231,
#  53: 323,
#  54: 236,
#  55: 203,
#  56: 147,
#  57: 210,
#  58: 191,
#  59: 288,
#  60: 179,
#  61: 188,
#  62: 197,
#  63: 236,
#  64: 222,
#  65: 222,
#  66: 168,
#  67: 211,
#  68: 200,
#  69: 236,
#  70: 242,
#  71: 155,
#  72: 219,
#  73: 221,
#  74: 104,
#  75: 210,
#  76: 234,
#  77: 134,
#  78: 220,
#  79: 204,
#  80: 147,
#  81: 256,
#  82: 206,
#  83: 149,
#  84: 225,
#  85: 205,
#  86: 173,
#  87: 139,
#  88: 105,
#  89: 184,
#  90: 209,
#  91: 206,
#  92: 155,
#  93: 178,
#  94: 154,
#  95: 200,
#  96: 515,
#  97: 167,
#  98: 184,
#  99: 202,
#  100: 176,
#  101: 208,
#  102: 50,
#  103: 80,
#  104: 205,
#  105: 132,
#  106: 307,
#  107: 228,
#  108: 159,
#  109: 367,
#  110: 245,
#  111: 238,
#  112: 175,
#  113: 224,
#  114: 202,
#  115: 132,
#  116: 176,
#  117: 248,
#  118: 230,
#  119: 125,
#  120: 119,
#  506: 237,
#  507: 209,
#  508: 220,
#  509: 278,
#  510: 199,
#  511: 242,
#  512: 166,
#  513: 271,
#  514: 122,
#  515: 303,
#  516: 204,
#  517: 228,
#  518: 216,
#  519: 222,
#  520: 169,
#  521: 283,
#  522: 173,
#  523: 195,
#  524: 220,
#  525: 281,
#  526: 168,
#  527: 267,
#  528: 110,
#  529: 216,
#  530: 52,
#  531: 201,
#  532: 85,
#  533: 229,
#  534: 175,
#  535: 208,
#  536: 176,
#  537: 218,
#  538: 160,
#  539: 193,
#  540: 82,
#  541: 156,
#  542: 166,
#  543: 239,
#  544: 99,
#  545: 180,
#  546: 154,
#  547: 241,
#  548: 146,
#  549: 103,
#  550: 173,
#  551: 183,
#  552: 181,
#  553: 246,
#  554: 133,
#  555: 161,
#  556: 130,
#  557: 211,
#  558: 197,
#  559: 200,
#  560: 118,
#  561: 87,
#  562: 197,
#  563: 119,
#  564: 269,
#  565: 156,
#  566: 251,
#  567: 177,
#  568: 214,
#  569: 73,
#  570: 124,
#  571: 214,
#  572: 183,
#  573: 208,
#  574: 281,
#  575: 46,
#  576: 232,
#  577: 170,
#  578: 176,
#  579: 197,
#  580: 231,
#  581: 214,
#  582: 180,
#  583: 242,
#  584: 73,
#  585: 214,
#  586: 125,
#  587: 185,
#  588: 360,
#  589: 197,
#  590: 209,
#  591: 237,
#  592: 280,
#  593: 198,
#  594: 213,
#  595: 149,
#  596: 227,
#  597: 145,
#  598: 203,
#  599: 134,
#  600: 204,
#  601: 110,
#  602: 120,
#  603: 106,
#  604: 160,
#  605: 275,
#  606: 162,
#  607: 225,
#  608: 214,
#  609: 149,
#  610: 128,
#  611: 161,
#  612: 179,
#  613: 187,
#  614: 180,
#  615: 217,
#  616: 235,
#  617: 55,
#  618: 231,
#  619: 172,
#  620: 191,
#  621: 299,
#  622: 308,
#  623: 78,
#  624: 281,
#  625: 202,
#  626: 332,
#  627: 64,
#  628: 117,
#  629: 170,
#  630: 185,
#  631: 254,
#  632: 138,
#  633: 219,
#  634: 167,
#  635: 217,
#  636: 218,
#  637: 211,
#  638: 125,
#  639: 200,
#  640: 194,
#  641: 166,
#  642: 121,
#  643: 210,
#  644: 183,
#  645: 127,
#  646: 191,
#  647: 186,
#  648: 208,
#  649: 193,
#  650: 127,
#  651: 149,
#  652: 254,
#  653: 302,
#  654: 81,
#  655: 183,
#  656: 221,
#  657: 200,
#  658: 222,
#  659: 170,
#  660: 184,
#  661: 203,
#  662: 210,
#  663: 185,
#  664: 72,
#  665: 54,
#  666: 353,
#  667: 64,
#  668: 108,
#  669: 223,
#  670: 259,
#  671: 267,
#  672: 219,
#  673: 156,
#  674: 174,
#  675: 137,
#  676: 223,
#  677: 122,
#  678: 239,
#  679: 134,
#  680: 80,
#  681: 126,
#  682: 137,
#  683: 135,
#  684: 160,
#  685: 216,
#  686: 182,
#  687: 157,
#  688: 136,
#  689: 257,
#  690: 232,
#  691: 192,
#  692: 88,
#  693: 140,
#  694: 186,
#  695: 198,
#  696: 174,
#  697: 162,
#  698: 235,
#  891: 187,
#  892: 216,
#  893: 215,
#  894: 226,
#  895: 227,
#  896: 117,
#  897: 184,
#  898: 276,
#  899: 128,
#  900: 229,
#  901: 100,
#  902: 215,
#  903: 169,
#  904: 169,
#  905: 102,
#  906: 321,
#  907: 140,
#  908: 296,
#  909: 202,
#  910: 152,
#  911: 199,
#  912: 69,
#  913: 234,
#  914: 221,
#  915: 183,
#  916: 151,
#  917: 200,
#  918: 204,
#  919: 282,
#  920: 321,
#  921: 320,
#  922: 217,
#  923: 112,
#  924: 189,
#  925: 155,
#  926: 206,
#  927: 228,
#  928: 302,
#  929: 202,
#  930: 198,
#  931: 239,
#  932: 171,
#  933: 279,
#  934: 210,
#  935: 222,
#  936: 221,
#  937: 174,
#  938: 165,
#  939: 213,
#  940: 166,
#  941: 231,
#  942: 225,
#  943: 187,
#  944: 104,
#  945: 173,
#  946: 204,
#  947: 231,
#  948: 340,
#  949: 205,
#  950: 193,
#  951: 226,
#  952: 163,
#  953: 211,
#  954: 217,
#  955: 285,
#  956: 166,
#  957: 193,
#  958: 207,
#  959: 165,
#  960: 218,
#  961: 112,
#  962: 188,
#  963: 225,
#  964: 218,
#  965: 158,
#  966: 332,
#  967: 127,
#  968: 128,
#  969: 176,
#  970: 122,
#  971: 149,
#  972: 160,
#  973: 239,
#  974: 185,
#  975: 81,
#  976: 93,
#  977: 136,
#  978: 243,
#  979: 139,
#  980: 99,
#  981: 205,
#  982: 203,
#  983: 127,
#  984: 81,
#  985: 95,
#  986: 120,
#  987: 135,
#  988: 211,
#  989: 258,
#  990: 276,
#  991: 164,
#  992: 162,
#  993: 153,
#  994: 42,
#  995: 225,
#  996: 176,
#  997: 251,
#  998: 463,
#  999: 163,
#  ...}

# %%
nltk.download('stopwords')

# Initialize tools
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
total_term_no_stop = {}
for doc_id, doc in data['text'].items():
  tokens = [word for word in doc.lower().split() if word not in stop_words]
  total_term_no_stop[doc_id] = len(tokens)

# %%
total_term_no_stop_df = pd.DataFrame.from_dict(total_term_no_stop, orient = 'index', columns = ['total_term_no_stop'])
round(total_term_no_stop_df['total_term_no_stop'].mean())
# Out:
# 147

# %%
total_term_no_stop
# Out:
# {0: 169,
#  1: 165,
#  2: 126,
#  3: 115,
#  4: 177,
#  5: 167,
#  6: 136,
#  7: 168,
#  8: 189,
#  9: 177,
#  10: 82,
#  11: 136,
#  12: 138,
#  13: 109,
#  14: 117,
#  15: 175,
#  16: 136,
#  17: 174,
#  18: 113,
#  19: 129,
#  20: 188,
#  21: 176,
#  22: 78,
#  23: 147,
#  24: 114,
#  25: 235,
#  26: 174,
#  27: 71,
#  28: 115,
#  29: 128,
#  30: 33,
#  31: 148,
#  32: 71,
#  33: 158,
#  34: 166,
#  35: 146,
#  36: 137,
#  37: 189,
#  38: 72,
#  39: 69,
#  40: 66,
#  41: 123,
#  42: 147,
#  43: 200,
#  44: 169,
#  45: 119,
#  46: 120,
#  47: 89,
#  48: 71,
#  49: 84,
#  50: 180,
#  51: 186,
#  52: 170,
#  53: 291,
#  54: 181,
#  633: 169,
#  634: 150,
#  635: 176,
#  636: 161,
#  637: 177,
#  638: 102,
#  639: 176,
#  640: 169,
#  641: 120,
#  642: 81,
#  643: 177,
#  644: 140,
#  645: 84,
#  646: 149,
#  647: 166,
#  648: 160,
#  649: 162,
#  650: 90,
#  651: 154,
#  652: 184,
#  653: 255,
#  654: 48,
#  655: 152,
#  656: 171,
#  657: 167,
#  658: 169,
#  659: 173,
#  660: 130,
#  661: 184,
#  662: 184,
#  663: 159,
#  664: 51,
#  665: 42,
#  666: 249,
#  667: 56,
#  668: 77,
#  669: 207,
#  670: 192,
#  671: 223,
#  672: 178,
#  673: 124,
#  674: 128,
#  675: 107,
#  676: 190,
#  677: 94,
#  678: 183,
#  679: 108,
#  680: 70,
#  681: 102,
#  682: 95,
#  683: 112,
#  684: 111,
#  685: 186,
#  686: 122,
#  687: 122,
#  688: 96,
#  689: 212,
#  690: 183,
#  691: 160,
#  692: 72,
#  693: 107,
#  694: 148,
#  695: 158,
#  696: 132,
#  697: 121,
#  698: 178,
#  699: 82,
#  700: 119,
#  701: 108,
#  702: 93,
#  703: 171,
#  704: 158,
#  705: 153,
#  706: 164,
#  707: 186,
#  708: 422,
#  709: 192,
#  710: 238,
#  711: 236,
#  712: 168,
#  713: 140,
#  714: 106,
#  715: 122,
#  716: 111,
#  717: 82,
#  718: 147,
#  719: 47,
#  720: 110,
#  721: 174,
#  722: 10,
#  723: 184,
#  724: 93,
#  725: 144,
#  726: 135,
#  727: 228,
#  728: 175,
#  729: 160,
#  730: 147,
#  731: 177,
#  732: 172,
#  733: 148,
#  734: 157,
#  735: 92,
#  736: 140,
#  737: 19,
#  738: 251,
#  739: 166,
#  740: 207,
#  741: 179,
#  742: 154,
#  743: 260,
#  744: 149,
#  745: 69,
#  746: 220,
#  747: 53,
#  748: 176,
#  749: 158,
#  750: 85,
#  751: 119,
#  752: 215,
#  753: 124,
#  754: 169,
#  755: 103,
#  756: 70,
#  757: 170,
#  758: 223,
#  759: 158,
#  760: 173,
#  761: 170,
#  762: 218,
#  763: 237,
#  764: 183,
#  765: 170,
#  766: 100,
#  767: 167,
#  768: 105,
#  769: 133,
#  770: 171,
#  771: 136,
#  772: 162,
#  773: 108,
#  774: 126,
#  775: 136,
#  776: 141,
#  777: 125,
#  778: 172,
#  779: 192,
#  780: 85,
#  781: 191,
#  782: 97,
#  783: 163,
#  784: 160,
#  785: 44,
#  786: 162,
#  787: 158,
#  788: 71,
#  789: 171,
#  790: 155,
#  791: 187,
#  792: 212,
#  793: 150,
#  794: 123,
#  795: 200,
#  796: 124,
#  797: 69,
#  798: 159,
#  799: 233,
#  800: 150,
#  801: 130,
#  802: 166,
#  803: 97,
#  804: 127,
#  805: 129,
#  806: 265,
#  807: 116,
#  808: 78,
#  809: 133,
#  810: 116,
#  811: 199,
#  812: 189,
#  813: 151,
#  814: 182,
#  815: 156,
#  816: 109,
#  817: 127,
#  818: 73,
#  819: 122,
#  820: 90,
#  821: 121,
#  822: 99,
#  823: 100,
#  824: 160,
#  825: 95,
#  826: 115,
#  827: 52,
#  828: 111,
#  829: 147,
#  830: 155,
#  831: 191,
#  832: 162,
#  833: 198,
#  834: 154,
#  835: 134,
#  836: 135,
#  837: 182,
#  838: 89,
#  839: 96,
#  840: 120,
#  841: 41,
#  842: 286,
#  843: 184,
#  844: 148,
#  845: 154,
#  846: 110,
#  847: 157,
#  848: 156,
#  849: 141,
#  850: 161,
#  851: 126,
#  852: 145,
#  853: 129,
#  854: 162,
#  855: 132,
#  856: 140,
#  857: 206,
#  858: 130,
#  859: 77,
#  860: 189,
#  861: 166,
#  862: 93,
#  863: 208,
#  864: 221,
#  865: 214,
#  866: 133,
#  867: 121,
#  868: 138,
#  869: 189,
#  870: 161,
#  871: 210,
#  872: 100,
#  873: 87,
#  874: 181,
#  875: 179,
#  876: 128,
#  877: 193,
#  878: 161,
#  879: 188,
#  880: 188,
#  881: 144,
#  882: 171,
#  883: 176,
#  884: 141,
#  885: 232,
#  886: 235,
#  887: 150,
#  888: 171,
#  889: 164,
#  890: 167,
#  891: 160,
#  892: 167,
#  893: 186,
#  894: 178,
#  895: 190,
#  896: 92,
#  897: 146,
#  898: 213,
#  899: 106,
#  900: 180,
#  901: 88,
#  902: 154,
#  903: 133,
#  904: 131,
#  905: 84,
#  906: 260,
#  907: 107,
#  908: 232,
#  909: 174,
#  910: 96,
#  911: 163,
#  912: 53,
#  913: 200,
#  914: 173,
#  915: 134,
#  916: 113,
#  917: 145,
#  918: 156,
#  919: 230,
#  920: 276,
#  921: 256,
#  922: 186,
#  923: 91,
#  924: 141,
#  925: 124,
#  926: 154,
#  927: 175,
#  928: 282,
#  929: 173,
#  930: 160,
#  931: 192,
#  932: 135,
#  933: 243,
#  934: 157,
#  935: 190,
#  936: 181,
#  937: 133,
#  938: 126,
#  939: 190,
#  940: 138,
#  941: 186,
#  942: 191,
#  943: 156,
#  944: 79,
#  945: 145,
#  946: 172,
#  947: 195,
#  948: 267,
#  949: 157,
#  950: 152,
#  951: 191,
#  952: 130,
#  953: 160,
#  954: 160,
#  955: 234,
#  956: 123,
#  957: 162,
#  958: 145,
#  959: 140,
#  960: 177,
#  961: 97,
#  962: 145,
#  963: 181,
#  964: 166,
#  965: 117,
#  966: 248,
#  967: 110,
#  968: 93,
#  969: 145,
#  970: 79,
#  971: 124,
#  972: 119,
#  973: 198,
#  974: 143,
#  975: 71,
#  976: 55,
#  977: 110,
#  978: 202,
#  979: 118,
#  980: 83,
#  981: 166,
#  982: 161,
#  983: 104,
#  984: 61,
#  985: 56,
#  986: 90,
#  987: 100,
#  988: 185,
#  989: 208,
#  990: 240,
#  991: 123,
#  992: 122,
#  993: 114,
#  994: 34,
#  995: 158,
#  996: 134,
#  997: 173,
#  998: 370,
#  999: 127,
#  ...}

# %%
relevant_counts = qrels_df[qrels_df["label"] > 0].groupby("qid").size()

unique_labels = qrels_df["label"].unique()

# Display Results
print("Relevant Documents per Query:\n", relevant_counts)
print("Relevance Labels:\n", unique_labels)

# Example visualization of relevance distribution
qrels_df[qrels_df["label"] > 0].groupby("label").size().plot(kind="bar")
plt.title("Relevance Label Distribution")
plt.xlabel("Relevance Label")
plt.ylabel("Number of Documents")
plt.show()
# Out:
# Relevant Documents per Query:
#  qid
# PLAIN-1008      5
# PLAIN-1018     60
# PLAIN-102      24
# PLAIN-1028      1
# PLAIN-1039      2
#              ...
# PLAIN-956     206
# PLAIN-966       3
# PLAIN-977       3
# PLAIN-987       3
# PLAIN-997       2
# Length: 323, dtype: int64
# Relevance Labels:
#  [2 1]

# %% [markdown]
# too much to be plotted :(

# %%
import numpy as np

# %%
# Out:
#             qid                                              query
# 0       PLAIN-2    Do Cholesterol Statin Drugs Cause Breast Cancer
# 1      PLAIN-12                Exploiting Autophagy to Live Longer
# 2      PLAIN-23  How to Reduce Exposure to Alkylphenols Through...
# 3      PLAIN-33             Whats Driving Americas Obesity Problem
# 4      PLAIN-44               Who Should be Careful About Curcumin
# ..          ...                                                ...
# 318  PLAIN-3432                       Healthy Chocolate Milkshakes
# 319  PLAIN-3442                          The Healthiest Vegetables
# 320  PLAIN-3452                           Bowel Movement Frequency
# 321  PLAIN-3462                      Olive Oil and Artery Function
# 322  PLAIN-3472  How Doctors Responded to Being Named a Leading...
#
# [323 rows x 2 columns]

# %%
token_counts = [len(query.split()) for query in queries['query']]

# Descriptive statistics
mean_tokens = np.mean(token_counts)
median_tokens = np.median(token_counts)
min_tokens = np.min(token_counts)
max_tokens = np.max(token_counts)
std_dev_tokens = np.std(token_counts)

# Print statistics
print(f"Mean tokens: {mean_tokens}")
print(f"Median tokens: {median_tokens}")
print(f"Min tokens: {min_tokens}")
print(f"Max tokens: {max_tokens}")
print(f"Standard deviation: {std_dev_tokens}")

# Plot histogram
plt.hist(token_counts, bins=range(min_tokens, max_tokens + 2), edgecolor='black', align='left')
plt.title("Distribution of Token Counts in Queries")
plt.xlabel("Number of Tokens")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean tokens: 3.2724458204334366
# Median tokens: 2.0
# Min tokens: 1
# Max tokens: 11
# Standard deviation: 2.4074347997767314

# %% [markdown]
# ### words cloud

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.11/dist-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
from wordcloud import WordCloud
term_frequencies = {}
for doc in data['text']:
    for word in doc.lower().split():
        term_frequencies[word] = term_frequencies.get(word, 0) + 1

top_n = 10
sorted_terms = sorted(term_frequencies.items(), key=lambda x: x[1], reverse=True)[:top_n]
limited_term_frequencies = dict(sorted_terms)

print(limited_term_frequencies)
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(limited_term_frequencies)
plt.figure(figsize=(20, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Term Distribution Word Cloud")
plt.show()
# Out:
# {'this': 2, 'is': 2, 'a': 1, 'sample': 1, 'text': 1, 'another': 1, 'example': 1}

# %%
plt.figure(figsize=(20, 10))
#plt.imshow(wordcloud, interpolation='bilinear')
#plt.axis('off')
#plt.title("Term Distribution Word Cloud")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Example data
data = {'text': ["This is a sample text", "This is another example"]}

# Compute term frequencies
term_frequencies = {}
for doc in data['text']:
    for word in doc.lower().split():
        term_frequencies[word] = term_frequencies.get(word, 0) + 1

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(term_frequencies)

# Plot word cloud
plt.figure(figsize=(20, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Term Distribution Word Cloud")
plt.show()

# %% [markdown]
# # MM copia

# %% [markdown]
# ## INDEXING THE COLLECTION (TITLE + TEXT) USING THE DEFAULT STEMMER

# %%
#We import Pyterrier and initiliaze it
import pyterrier as pt
import os

#Directory to store the index
pt_index_path = './antonio'

#Convert the dataset in a list of dictionaries
corpus = data.to_dict(orient='records')

# Index the collection (title + text) using the default stemmer and save as meta data: text, title and doc_id

if not os.path.exists(pt_index_path + "/data.properties"):
  indexer = pt.index.IterDictIndexer(pt_index_path, meta={'docno':20, 'text':2000, 'title':100}, text_attrs = ['title'])
  index_ref = indexer.index(corpus)
else:
  index_ref = pt.IndexRef.of(pt_index_path + "/data.properties")

index = pt.IndexFactory.of(index_ref)

print('Collection Statistics',index.getCollectionStatistics().toString())
# Out:
# terrier-assemblies 5.11 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.8 jar not found, downloading to /root/.pyterrier...
# Done
# Java started (triggered by TerrierIndexer.__init__) and loaded: pyterrier.java, pyterrier.terrier.java [version=5.11 (build: craig.macdonald 2025-01-13 21:29), helper_version=0.0.8]
# Collection Statistics Number of documents: 3633
# Number of terms: 5075
# Number of postings: 33108
# Number of fields: 0
# Number of tokens: 33787
# Field names: []
# Positions:   false

# %% [markdown]
# ## SETTING THE PIPELINE (BM25-TFIDF) AND RUNNING THE EXPERIMENTS DEFAULT

# %%
#We set the pipeline
tf_idf = pt.terrier.Retriever(index, wmodel="TF_IDF")
bm25 = pt.terrier.Retriever(index, wmodel="BM25")
pipeline = (bm25 % 100) >> tf_idf

# %%
#Now we can run the pipeline
results_pipeline = pipeline.transform(queries)
results_pipeline = adjust_qrels(results_pipeline, qrels_df)

# %%
evaluate_pipeline_bm25_tfidf_default = pt.Evaluate(results_pipeline, qrels_df, metrics=['map', 'P_10', 'recall_25', 'ndcg'])
display(evaluate_pipeline_bm25_tfidf_default)
# Out:
# /usr/local/lib/python3.10/dist-packages/ranx/metrics/ndcg.py:72: NumbaTypeSafetyWarning: unsafe cast from uint64 to int64. Precision may be lost.
#   scores[i] = _ndcg(qrels[i], run[i], k, rel_lvl, jarvelin)
# {'map': 0.3621066039061444,
#  'P_10': 0.1687306501547989,
#  'recall_25': 0.1384755243657402,
#  'ndcg': 0.19014391724343058}

# %%
#Evaluate the pipeline performances on each query
evaluate_pipeline_per_query = pt.Evaluate(results_pipeline, qrels_df, metrics=['map', 'P_10', 'recall_25', 'ndcg'], perquery=True)

# %%
#We convert the results of the pipeline_per_query in a Dataframe
evaluate_pipeline_per_query_df = pd.DataFrame(evaluate_pipeline_per_query)

#Transpose the Dataframe
evaluate_pipeline_per_query_df = evaluate_pipeline_per_query_df.T

#Exclude all the queries which do not appear in the queries dataset
evaluate_pipeline_per_query_df = evaluate_pipeline_per_query_df[evaluate_pipeline_per_query_df.index.isin(queries['qid'])]

# %%
#We save the results in a CSV and download it
evaluate_pipeline_per_query_df.to_csv('bm25_tfidf_default.csv')
files.download('bm25_tfidf_default.csv')

# %% [markdown]
# ## Neural Reranking of pipeline (BM25 TF-IDF) DEFAULT STEMMER

# %%
#We use BERT to neural re-rank the pipeline. We specify that it will recive as input the titles of the documents.
vbert = onir_pt.reranker(
    'vanilla_transformer', 'bert',
    text_field='title',
    vocab_config={'train': True}
)
#We create the neural pipeline. We use the titles of the documents, which we have saved as metadata in the indexing, to re-rank.
neural_pipeline = pipeline >> pt.text.get_text(indexlike=index, metadata='title') >> vbert
# Out:
# config file not found: config
# 100%|██████████| 231508/231508 s<0ms, 1302533.03B/s]
# 100%|██████████| 433/433 s<0ms, 436360.80B/s]
# 100%|██████████| 440473133/440473133 [9.30s<0ms, 47349456.97B/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_transformers/modeling_utils.py:477: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(resolved_archive_file, map_location='cpu')

# %%
#Now we can run the pipeline
results_pipeline = neural_pipeline.transform(queries)
results_pipeline = adjust_qrels(results_pipeline, qrels_df)
# Out:
# [2025-01-15 19:51:19,963][onir_pt][DEBUG] using GPU (deterministic)
# [2025-01-15 19:51:20,489][onir_pt][DEBUG] [starting] batches
# batches:   0%|          | 0/3813 s<?, ?it/s]
# [2025-01-15 19:52:31,917][onir_pt][DEBUG] [finished] batches: [01:11] [3813it] [53.38it/s]

# %%
#Evaluates the pipeline overall perfomances
evaluate_pipeline_bm25_tfid_default_neural = pt.Evaluate(results_pipeline, qrels_df, metrics=['map', 'P_10', 'recall_25', 'ndcg'])
display(evaluate_pipeline_bm25_tfid_default_neural)
# Out:
# {'map': 0.23964601686775233,
#  'P_10': 0.10526315789473695,
#  'recall_25': 0.10314990251040387,
#  'ndcg': 0.1374106119398779}

# %% [markdown]
# ## INDEXING THE COLLECTION (TITLE + TEXT) USING THE WEAKPORTER STEMMER

# %%
#We import Pyterrier and initiliaze it
import pyterrier as pt
import os

#Directory to store the index
pt_index_path = './claudio'

#Convert the dataset in a list of dictionaries
corpus = data.to_dict(orient='records')

# Index the collection (title + text) using the default stemmer and save as meta data: text, title and doc_id
if not os.path.exists(pt_index_path + "/data.properties"):
  indexer = pt.index.IterDictIndexer(pt_index_path, meta={'docno':20, 'text':2000, 'title':100}, text_attrs = ['text', 'title'], stemmer = pt.TerrierStemmer.weakporter)
  index_ref = indexer.index(corpus)
else:
  index_ref = pt.IndexRef.of(pt_index_path + "/data.properties")

index = pt.IndexFactory.of(index_ref)

print('Collection Statistics',index.getCollectionStatistics().toString())
# Out:
# Collection Statistics Number of documents: 3633
# Number of terms: 21500
# Number of postings: 345574
# Number of fields: 0
# Number of tokens: 567901
# Field names: []
# Positions:   false

# %% [markdown]
# ## SETTING THE PIPELINE (BM25-TFIDF) AND RUNNING THE EXPERIMENTS WEAK PORTER

# %%
#We set the pipeline
tf_idf = pt.terrier.Retriever(index, wmodel="TF_IDF")
bm25 = pt.terrier.Retriever(index, wmodel="BM25")
pipeline = (bm25 % 100) >> tf_idf

# %%
#Now we can run the pipeline
results_pipeline = pipeline.transform(queries)
results_pipeline = adjust_qrels(results_pipeline, qrels_df)

# %%
evaluate_pipeline_bm25_tfidf_default = pt.Evaluate(results_pipeline, qrels_df, metrics=['map', 'P_10', 'recall_25', 'ndcg'])
display(evaluate_pipeline_bm25_tfidf_default)
# Out:
# {'map': 0.39514049569665693,
#  'P_10': 0.23219814241486056,
#  'recall_25': 0.1852769739839275,
#  'ndcg': 0.2565750437414397}

# %%
#Evaluate the pipeline performances on each query
evaluate_pipeline_per_query = pt.Evaluate(results_pipeline, qrels_df, metrics=['map', 'P_10', 'recall_25', 'ndcg'], perquery=True)

# %%
#We convert the results of the pipeline_per_query in a Dataframe
evaluate_pipeline_per_query_df = pd.DataFrame(evaluate_pipeline_per_query)

#Transpose the Dataframe
evaluate_pipeline_per_query_df = evaluate_pipeline_per_query_df.T

#Exclude all the queries which do not appear in the queries dataset
evaluate_pipeline_per_query_df = evaluate_pipeline_per_query_df[evaluate_pipeline_per_query_df.index.isin(queries['qid'])]

# %%
#We save the results in a CSV and download it
evaluate_pipeline_per_query_df.to_csv('bm25_tfidf_default.csv')
files.download('bm25_tfidf_default.csv')

# %% [markdown]
# ## Neural Reranking of pipeline (BM25 TF-IDF) WEAKPORTER

# %%
#We use BERT to neural re-rank the pipeline. We specify that it will recive as input the titles of the documents.
vbert = onir_pt.reranker(
    'vanilla_transformer', 'bert',
    text_field='title',
    vocab_config={'train': True}
)
#We create the neural pipeline. We use the titles of the documents, which we have saved as metadata in the indexing, to re-rank.
neural_pipeline = pipeline >> pt.text.get_text(indexlike=index, metadata='title') >> vbert
# Out:
# /usr/local/lib/python3.10/dist-packages/pytorch_transformers/modeling_utils.py:477: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(resolved_archive_file, map_location='cpu')

# %%
#Now we can run the pipeline
results_pipeline = neural_pipeline.transform(queries)
results_pipeline = adjust_qrels(results_pipeline, qrels_df)
# Out:
# [2025-01-15 19:55:31,645][onir_pt][DEBUG] using GPU (deterministic)
# [2025-01-15 19:55:31,806][onir_pt][DEBUG] [starting] batches
# batches:   0%|          | 0/5274 s<?, ?it/s]
# [2025-01-15 19:57:02,584][onir_pt][DEBUG] [finished] batches: [01:31] [5274it] [58.10it/s]

# %%
#Evaluates the pipeline overall perfomances
evaluate_pipeline_bm25_tfid_default_neural = pt.Evaluate(results_pipeline, qrels_df, metrics=['map', 'P_10', 'recall_25', 'ndcg'])
display(evaluate_pipeline_bm25_tfid_default_neural)
# Out:
# {'map': 0.20763650540672982,
#  'P_10': 0.09845201238390103,
#  'recall_25': 0.10117473759280424,
#  'ndcg': 0.1648878518133511}

# %% [markdown]
# ## INDEXING THE COLLECTION (TITLE + TEXT) USING NO STEMMER

# %%
#We import Pyterrier and initiliaze it
import pyterrier as pt
import os

#Directory to store the index
pt_index_path = './demitrio'

#Convert the dataset in a list of dictionaries
corpus = data.to_dict(orient='records')

# Index the collection (title + text) using the default stemmer and save as meta data: text, title and doc_id
if not os.path.exists(pt_index_path + "/data.properties"):
  indexer = pt.index.IterDictIndexer(pt_index_path, meta={'docno':20, 'text':2000, 'title':100}, text_attrs = ['title'], stemmer = pt.TerrierStemmer.none)
  index_ref = indexer.index(corpus)
else:
  index_ref = pt.IndexRef.of(pt_index_path + "/data.properties")

index = pt.IndexFactory.of(index_ref)

print('Collection Statistics',index.getCollectionStatistics().toString())
# Out:
# Collection Statistics Number of documents: 3633
# Number of terms: 6453
# Number of postings: 33201
# Number of fields: 0
# Number of tokens: 33787
# Field names: []
# Positions:   false

# %% [markdown]
# ## SETTING THE PIPELINE (BM25-TFIDF) AND RUNNING THE EXPERIMENTS NO STEMMER

# %%
#We set the pipeline
tf_idf = pt.terrier.Retriever(index, wmodel="TF_IDF")
bm25 = pt.terrier.Retriever(index, wmodel="BM25")
pipeline = (bm25 % 100) >> tf_idf

# %%
#Now we can run the pipeline
results_pipeline = pipeline.transform(queries)
results_pipeline = adjust_qrels(results_pipeline, qrels_df)

# %%
evaluate_pipeline_bm25_tfidf_default = pt.Evaluate(results_pipeline, qrels_df, metrics=['map', 'P_10', 'recall_25', 'ndcg'])
display(evaluate_pipeline_bm25_tfidf_default)
# Out:
# {'map': 0.3414209745488222,
#  'P_10': 0.1433436532507742,
#  'recall_25': 0.12364491866950258,
#  'ndcg': 0.1658606787744923}

# %%
#Evaluate the pipeline performances on each query
evaluate_pipeline_per_query = pt.Evaluate(results_pipeline, qrels_df, metrics=['map', 'P_10', 'recall_25', 'ndcg'], perquery=True)

# %%
#We convert the results of the pipeline_per_query in a Dataframe
evaluate_pipeline_per_query_df = pd.DataFrame(evaluate_pipeline_per_query)

#Transpose the Dataframe
evaluate_pipeline_per_query_df = evaluate_pipeline_per_query_df.T

#Exclude all the queries which do not appear in the queries dataset
evaluate_pipeline_per_query_df = evaluate_pipeline_per_query_df[evaluate_pipeline_per_query_df.index.isin(queries['qid'])]

# %%
#We save the results in a CSV and download it
evaluate_pipeline_per_query_df.to_csv('bm25_tfidf_default.csv')
files.download('bm25_tfidf_default.csv')

# %% [markdown]
# ## Neural Reranking of pipeline (BM25 TF-IDF) NO STEMMER

# %%
#We use BERT to neural re-rank the pipeline. We specify that it will recive as input the titles of the documents.
vbert = onir_pt.reranker(
    'vanilla_transformer', 'bert',
    text_field='title',
    vocab_config={'train': True}
)
#We create the neural pipeline. We use the titles of the documents, which we have saved as metadata in the indexing, to re-rank.
neural_pipeline = pipeline >> pt.text.get_text(indexlike=index, metadata='title') >> vbert
# Out:
# /usr/local/lib/python3.10/dist-packages/pytorch_transformers/modeling_utils.py:477: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(resolved_archive_file, map_location='cpu')

# %%
#Now we can run the pipeline
results_pipeline = neural_pipeline.transform(queries)
results_pipeline = adjust_qrels(results_pipeline, qrels_df)
# Out:
# [2025-01-15 19:59:48,701][onir_pt][DEBUG] using GPU (deterministic)
# [2025-01-15 19:59:48,836][onir_pt][DEBUG] [starting] batches
# batches:   0%|          | 0/3270 s<?, ?it/s]
# [2025-01-15 20:00:46,108][onir_pt][DEBUG] [finished] batches: [57.27s] [3270it] [57.10it/s]

# %%
#Evaluates the pipeline overall perfomances
evaluate_pipeline_bm25_tfid_default_neural = pt.Evaluate(results_pipeline, qrels_df, metrics=['map', 'P_10', 'recall_25', 'ndcg'])
display(evaluate_pipeline_bm25_tfid_default_neural)
# Out:
# {'map': 0.2412589994035995,
#  'P_10': 0.09349845201238399,
#  'recall_25': 0.09430946568956919,
#  'ndcg': 0.12583565059982063}

# %% [markdown]
# # Best/Worst queries

# %% [markdown]
# reading all the csv and merging together

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## import df bm25 tfidf pipeline

# %%
df_bm25_tfidf_1 = pd.read_csv('drive/MyDrive/Colab Notebooks/Magistrale/IR/bm25_tfidf_default.csv')
df_bm25_tfidf_1.rename(columns={'Unnamed: 0': 'qid'}, inplace = True)
df_bm25_tfidf_1
# Out:
#             qid  P_10       map      ndcg  recall_25
# 0       PLAIN-2   0.7  0.602967  0.778351   0.458333
# 1      PLAIN-12   0.1  0.200000  0.060448   0.033333
# 2      PLAIN-23   0.8  0.551268  0.332545   0.088889
# 3      PLAIN-33   0.2  0.331759  0.223693   0.062500
# 4      PLAIN-44   0.2  0.187655  0.210730   0.068966
# ..          ...   ...       ...       ...        ...
# 318  PLAIN-2134   0.0  0.000000  0.000000   0.000000
# 319  PLAIN-1679   0.0  0.000000  0.000000   0.000000
# 320  PLAIN-2408   0.0  0.000000  0.000000   0.000000
# 321   PLAIN-997   0.0  0.000000  0.000000   0.000000
# 322  PLAIN-1611   0.0  0.000000  0.000000   0.000000
#
# [323 rows x 5 columns]

# %%
df_bm25_tfidf_2 = pd.read_csv('drive/MyDrive/Colab Notebooks/Magistrale/IR/bm25_tfidf_weak_porter.csv')
df_bm25_tfidf_2.rename(columns={'Unnamed: 0': 'qid'}, inplace = True)
df_bm25_tfidf_2
# Out:
#             qid  P_10       map      ndcg  recall_25
# 0       PLAIN-2   0.6  0.564411  0.765618   0.416667
# 1      PLAIN-12   0.1  0.200000  0.060448   0.033333
# 2      PLAIN-23   0.5  0.610925  0.297864   0.100000
# 3      PLAIN-33   0.2  0.280382  0.236305   0.062500
# 4      PLAIN-44   0.1  0.163297  0.182426   0.051724
# ..          ...   ...       ...       ...        ...
# 318  PLAIN-2134   0.0  0.000000  0.000000   0.000000
# 319  PLAIN-1679   0.0  0.000000  0.000000   0.000000
# 320  PLAIN-2408   0.0  0.000000  0.000000   0.000000
# 321   PLAIN-997   0.0  0.000000  0.000000   0.000000
# 322  PLAIN-1611   0.0  0.000000  0.000000   0.000000
#
# [323 rows x 5 columns]

# %%
df_bm25_tfidf_3 = pd.read_csv('drive/MyDrive/Colab Notebooks/Magistrale/IR/bm25_tfidf_no_stemmer.csv')
df_bm25_tfidf_3.rename(columns={'Unnamed: 0': 'qid'}, inplace = True)
df_bm25_tfidf_3
# Out:
#             qid  P_10       map      ndcg  recall_25
# 0       PLAIN-2   0.4  0.474648  0.631728   0.291667
# 1      PLAIN-12   0.0  0.000000  0.000000   0.000000
# 2      PLAIN-23   0.5  0.311561  0.172310   0.066667
# 3      PLAIN-33   0.2  0.146941  0.207999   0.093750
# 4      PLAIN-44   0.0  0.157213  0.158664   0.068966
# ..          ...   ...       ...       ...        ...
# 318  PLAIN-2880   0.0  0.000000  0.000000   0.000000
# 319  PLAIN-3131   0.0  0.000000  0.000000   0.000000
# 320  PLAIN-1621   0.0  0.000000  0.000000   0.000000
# 321  PLAIN-1363   0.0  0.000000  0.000000   0.000000
# 322  PLAIN-1611   0.0  0.000000  0.000000   0.000000
#
# [323 rows x 5 columns]

# %% [markdown]
# ## import df tfidf bm25 pipeline

# %%
df_tfidf_bm25_1 = pd.read_csv('drive/MyDrive/Colab Notebooks/Magistrale/IR/tfidf_bm25_default.csv')
df_tfidf_bm25_1.rename(columns={'Unnamed: 0': 'qid'}, inplace = True)
df_tfidf_bm25_1
# Out:
#             qid       map  P_10      ndcg  recall_25
# 0       PLAIN-2  0.629057   0.7  0.766694   0.458333
# 1      PLAIN-12  0.200000   0.1  0.060448   0.033333
# 2      PLAIN-23  0.668309   0.8  0.325125   0.088889
# 3      PLAIN-33  0.239405   0.2  0.256239   0.062500
# 4      PLAIN-44  0.198861   0.2  0.214485   0.068966
# ..          ...       ...   ...       ...        ...
# 318  PLAIN-2271  0.000000   0.0  0.000000   0.000000
# 319  PLAIN-2408  0.000000   0.0  0.000000   0.000000
# 320   PLAIN-551  0.000000   0.0  0.000000   0.000000
# 321  PLAIN-1621  0.000000   0.0  0.000000   0.000000
# 322  PLAIN-1098  0.000000   0.0  0.000000   0.000000
#
# [323 rows x 5 columns]

# %%
df_tfidf_bm25_2 = pd.read_csv('drive/MyDrive/Colab Notebooks/Magistrale/IR/tfidf_bm25_weak_porter.csv')
df_tfidf_bm25_2.rename(columns={'Unnamed: 0': 'qid'}, inplace = True)
df_tfidf_bm25_2
# Out:
#             qid  P_10       map      ndcg  recall_25
# 0       PLAIN-2   0.6  0.585980  0.748091   0.416667
# 1      PLAIN-12   0.1  0.200000  0.060448   0.033333
# 2      PLAIN-23   0.8  0.680343  0.326287   0.100000
# 3      PLAIN-33   0.2  0.242724  0.257736   0.062500
# 4      PLAIN-44   0.1  0.173239  0.187662   0.051724
# ..          ...   ...       ...       ...        ...
# 318  PLAIN-1008   0.0  0.000000  0.000000   0.000000
# 319  PLAIN-1611   0.0  0.000000  0.000000   0.000000
# 320  PLAIN-2209   0.0  0.000000  0.000000   0.000000
# 321  PLAIN-1679   0.0  0.000000  0.000000   0.000000
# 322  PLAIN-2396   0.0  0.000000  0.000000   0.000000
#
# [323 rows x 5 columns]

# %%
df_tfidf_bm25_3 = pd.read_csv('drive/MyDrive/Colab Notebooks/Magistrale/IR/tfidf_bm25_no_stemmer.csv')
df_tfidf_bm25_3.rename(columns={'Unnamed: 0': 'qid'}, inplace = True)
df_tfidf_bm25_3
# Out:
#             qid  P_10       map      ndcg  recall_25
# 0       PLAIN-2   0.4  0.497106  0.638526   0.333333
# 1      PLAIN-12   0.0  0.000000  0.000000   0.000000
# 2      PLAIN-23   0.5  0.312373  0.172373   0.066667
# 3      PLAIN-33   0.2  0.146941  0.207999   0.093750
# 4      PLAIN-44   0.0  0.157213  0.158360   0.068966
# ..          ...   ...       ...       ...        ...
# 318  PLAIN-1331   0.0  0.000000  0.000000   0.000000
# 319   PLAIN-817   0.0  0.000000  0.000000   0.000000
# 320  PLAIN-1309   0.0  0.000000  0.000000   0.000000
# 321   PLAIN-583   0.0  0.000000  0.000000   0.000000
# 322   PLAIN-499   0.0  0.000000  0.000000   0.000000
#
# [323 rows x 5 columns]

# %% [markdown]
# ## import df tfidf bm25 models

# %%
df_tfidf_1 = pd.read_csv('drive/MyDrive/Colab Notebooks/Magistrale/IR/tfidf_default.csv')
df_tfidf_1.rename(columns={'Unnamed: 0': 'qid'}, inplace = True)
df_tfidf_1
# Out:
#             qid  P_10       map  recall_25      ndcg
# 0       PLAIN-2   0.7  0.505938   0.458333  0.820251
# 1      PLAIN-12   0.1  0.079710   0.033333  0.082815
# 2      PLAIN-23   0.8  0.247876   0.088889  0.468726
# 3      PLAIN-33   0.2  0.147796   0.062500  0.336384
# 4      PLAIN-44   0.2  0.128289   0.068966  0.274872
# ..          ...   ...       ...        ...       ...
# 318   PLAIN-997   0.0  0.000000   0.000000  0.000000
# 319  PLAIN-1679   0.0  0.000000   0.000000  0.000000
# 320  PLAIN-1309   0.0  0.000000   0.000000  0.000000
# 321  PLAIN-2209   0.0  0.000000   0.000000  0.000000
# 322  PLAIN-1098   0.0  0.000000   0.000000  0.000000
#
# [323 rows x 5 columns]

# %%
df_bm25_1 = pd.read_csv('drive/MyDrive/Colab Notebooks/Magistrale/IR/bm25_default.csv')
df_bm25_1.rename(columns={'Unnamed: 0': 'qid'}, inplace = True)
df_bm25_1
# Out:
#             qid  P_10       map  recall_25      ndcg
# 0       PLAIN-2   0.7  0.488793   0.458333  0.831714
# 1      PLAIN-12   0.1  0.079762   0.033333  0.082846
# 2      PLAIN-23   0.8  0.272577   0.088889  0.503403
# 3      PLAIN-33   0.2  0.147316   0.062500  0.335465
# 4      PLAIN-44   0.2  0.134542   0.068966  0.278511
# ..          ...   ...       ...        ...       ...
# 318   PLAIN-997   0.0  0.000000   0.000000  0.000000
# 319  PLAIN-1679   0.0  0.000000   0.000000  0.000000
# 320  PLAIN-1309   0.0  0.000000   0.000000  0.000000
# 321  PLAIN-2209   0.0  0.000000   0.000000  0.000000
# 322  PLAIN-1098   0.0  0.000000   0.000000  0.000000
#
# [323 rows x 5 columns]

# %% [markdown]
# ## Merge

# %%
df = pd.merge(df_bm25_tfidf_1, df_bm25_tfidf_2, on = 'qid', how = 'outer', suffixes=('_bm25_tfidf_default', '_bm25_tfidf_weak_porter'))
df = pd.merge(df, df_bm25_tfidf_3, on = 'qid', how = 'outer')
df = pd.merge(df, df_tfidf_bm25_1, on = 'qid', how = 'outer', suffixes = ('_bm25_tfidf_no_stemmer', '_tfidf_bm25_default'))
df = pd.merge(df, df_tfidf_bm25_2, on = 'qid', how = 'outer')
df = pd.merge(df, df_tfidf_bm25_3, on = 'qid', how = 'outer', suffixes = ('_tfidf_bm25_weak_porter', '_tfidf_bm25_no_stemmer'))
df = pd.merge(df, df_tfidf_1, on = 'qid', how = 'outer')
df = pd.merge(df, df_bm25_1, on = 'qid', how = 'outer', suffixes = ('_tfidf_default', '_bm25_default'))
df
# Out:
#             qid  P_10_bm25_tfidf_default  map_bm25_tfidf_default  \
# 0    PLAIN-1008                      0.0                0.000000
# 1    PLAIN-1018                      0.6                0.538758
# 2     PLAIN-102                      0.1                0.200000
# 3    PLAIN-1028                      0.0                0.000000
# 4    PLAIN-1039                      0.2                1.000000
# ..          ...                      ...                     ...
# 318   PLAIN-956                      0.5                0.499266
# 319   PLAIN-966                      0.1                0.100000
# 320   PLAIN-977                      0.0                0.071429
# 321   PLAIN-987                      0.1                0.333333
# 322   PLAIN-997                      0.0                0.000000
#
#      ndcg_bm25_tfidf_default  recall_25_bm25_tfidf_default  \
# 0                   0.000000                      0.000000
# 1                   0.195075                      0.133333
# 2                   0.081017                      0.041667
# 3                   0.000000                      0.000000
# 4                   1.000000                      1.000000
# ..                       ...                           ...
# 318                 0.226991                      0.072816
# 319                 0.135652                      0.333333
# 320                 0.120116                      0.333333
# 321                 0.234639                      0.333333
# 322                 0.000000                      0.000000
#
#      P_10_bm25_tfidf_weak_porter  map_bm25_tfidf_weak_porter  \
# 0                            0.0                    0.000000
# 1                            0.6                    0.538758
# 2                            0.1                    0.200000
# 3                            0.0                    0.000000
# 4                            0.2                    1.000000
# ..                           ...                         ...
# 318                          0.5                    0.499266
# 319                          0.1                    0.100000
# 320                          0.0                    0.071429
# 321                          0.1                    0.333333
# 322                          0.0                    0.000000
#
#      ndcg_bm25_tfidf_weak_porter  recall_25_bm25_tfidf_weak_porter  \
# 0                       0.000000                          0.000000
# 1                       0.195075                          0.133333
# 2                       0.081017                          0.041667
# 3                       0.000000                          0.000000
# 4                       1.000000                          1.000000
# ..                           ...                               ...
# 318                     0.226991                          0.072816
# 319                     0.135652                          0.333333
# 320                     0.120116                          0.333333
# 321                     0.234639                          0.333333
# 322                     0.000000                          0.000000
#
#      P_10_bm25_tfidf_no_stemmer  ...  ndcg_tfidf_bm25_no_stemmer  \
# 0                           0.0  ...                    0.000000
# 1                           0.0  ...                    0.000000
# 2                           0.0  ...                    0.033834
# 3                           0.0  ...                    0.270238
# 4                           0.1  ...                    0.613147
# ..                          ...  ...                         ...
# 318                         0.4  ...                    0.089138
# 319                         0.0  ...                    0.000000
# 320                         0.0  ...                    0.123256
# 321                         0.0  ...                    0.000000
# 322                         0.0  ...                    0.000000
#
#      recall_25_tfidf_bm25_no_stemmer  P_10_tfidf_default  map_tfidf_default  \
# 0                           0.000000                 0.0           0.000000
# 1                           0.000000                 0.6           0.538758
# 2                           0.000000                 0.1           0.034496
# 3                           1.000000                 0.0           0.002364
# 4                           0.500000                 0.2           1.000000
# ..                               ...                 ...                ...
# 318                         0.048544                 0.5           0.315086
# 319                         0.000000                 0.1           0.100000
# 320                         0.333333                 0.0           0.071429
# 321                         0.000000                 0.1           0.333333
# 322                         0.000000                 0.0           0.000000
#
#      recall_25_tfidf_default  ndcg_tfidf_default  P_10_bm25_default  \
# 0                   0.000000            0.000000                0.0
# 1                   0.133333            0.195075                0.6
# 2                   0.041667            0.194871                0.1
# 3                   0.000000            0.114575                0.0
# 4                   1.000000            1.000000                0.2
# ..                       ...                 ...                ...
# 318                 0.072816            0.408654                0.6
# 319                 0.333333            0.135652                0.1
# 320                 0.333333            0.120116                0.0
# 321                 0.333333            0.234639                0.1
# 322                 0.000000            0.000000                0.0
#
#      map_bm25_default  recall_25_bm25_default  ndcg_bm25_default
# 0            0.000000                0.000000           0.000000
# 1            0.538758                0.133333           0.195075
# 2            0.033877                0.041667           0.193503
# 3            0.002278                0.000000           0.113878
# 4            1.000000                1.000000           1.000000
# ..                ...                     ...                ...
# 318          0.324810                0.067961           0.412933
# 319          0.100000                0.333333           0.135652
# 320          0.071429                0.333333           0.120116
# 321          0.333333                0.333333           0.234639
# 322          0.000000                0.000000           0.000000
#
# [323 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['qid', 'P_10_bm25_tfidf_default', 'map_bm25_tfidf_default',
#        'ndcg_bm25_tfidf_default', 'recall_25_bm25_tfidf_default',
#        'P_10_bm25_tfidf_weak_porter', 'map_bm25_tfidf_weak_porter',
#        'ndcg_bm25_tfidf_weak_porter', 'recall_25_bm25_tfidf_weak_porter',
#        'P_10_bm25_tfidf_no_stemmer', 'map_bm25_tfidf_no_stemmer',
#        'ndcg_bm25_tfidf_no_stemmer', 'recall_25_bm25_tfidf_no_stemmer',
#        'map_tfidf_bm25_default', 'P_10_tfidf_bm25_default',
#        'ndcg_tfidf_bm25_default', 'recall_25_tfidf_bm25_default',
#        'P_10_tfidf_bm25_weak_porter', 'map_tfidf_bm25_weak_porter',
#        'ndcg_tfidf_bm25_weak_porter', 'recall_25_tfidf_bm25_weak_porter',
#        'P_10_tfidf_bm25_no_stemmer', 'map_tfidf_bm25_no_stemmer',
#        'ndcg_tfidf_bm25_no_stemmer', 'recall_25_tfidf_bm25_no_stemmer',
#        'P_10_tfidf_default', 'map_tfidf_default', 'recall_25_tfidf_default',
#        'ndcg_tfidf_default', 'P_10_bm25_default', 'map_bm25_default',
#        'recall_25_bm25_default', 'ndcg_bm25_default'],
#       dtype='object')

# %% [markdown]
# ## best worst queries

# %%
df
# Out:
#             qid  P_10_bm25_tfidf_default  map_bm25_tfidf_default  \
# 0    PLAIN-1008                      0.0                0.000000
# 1    PLAIN-1018                      0.6                0.538758
# 2     PLAIN-102                      0.1                0.200000
# 3    PLAIN-1028                      0.0                0.000000
# 4    PLAIN-1039                      0.2                1.000000
# ..          ...                      ...                     ...
# 318   PLAIN-956                      0.5                0.499266
# 319   PLAIN-966                      0.1                0.100000
# 320   PLAIN-977                      0.0                0.071429
# 321   PLAIN-987                      0.1                0.333333
# 322   PLAIN-997                      0.0                0.000000
#
#      ndcg_bm25_tfidf_default  recall_25_bm25_tfidf_default  \
# 0                   0.000000                      0.000000
# 1                   0.195075                      0.133333
# 2                   0.081017                      0.041667
# 3                   0.000000                      0.000000
# 4                   1.000000                      1.000000
# ..                       ...                           ...
# 318                 0.226991                      0.072816
# 319                 0.135652                      0.333333
# 320                 0.120116                      0.333333
# 321                 0.234639                      0.333333
# 322                 0.000000                      0.000000
#
#      P_10_bm25_tfidf_weak_porter  map_bm25_tfidf_weak_porter  \
# 0                            0.0                    0.000000
# 1                            0.6                    0.538758
# 2                            0.1                    0.200000
# 3                            0.0                    0.000000
# 4                            0.2                    1.000000
# ..                           ...                         ...
# 318                          0.5                    0.499266
# 319                          0.1                    0.100000
# 320                          0.0                    0.071429
# 321                          0.1                    0.333333
# 322                          0.0                    0.000000
#
#      ndcg_bm25_tfidf_weak_porter  recall_25_bm25_tfidf_weak_porter  \
# 0                       0.000000                          0.000000
# 1                       0.195075                          0.133333
# 2                       0.081017                          0.041667
# 3                       0.000000                          0.000000
# 4                       1.000000                          1.000000
# ..                           ...                               ...
# 318                     0.226991                          0.072816
# 319                     0.135652                          0.333333
# 320                     0.120116                          0.333333
# 321                     0.234639                          0.333333
# 322                     0.000000                          0.000000
#
#      P_10_bm25_tfidf_no_stemmer  ...  ndcg_tfidf_bm25_no_stemmer  \
# 0                           0.0  ...                    0.000000
# 1                           0.0  ...                    0.000000
# 2                           0.0  ...                    0.033834
# 3                           0.0  ...                    0.270238
# 4                           0.1  ...                    0.613147
# ..                          ...  ...                         ...
# 318                         0.4  ...                    0.089138
# 319                         0.0  ...                    0.000000
# 320                         0.0  ...                    0.123256
# 321                         0.0  ...                    0.000000
# 322                         0.0  ...                    0.000000
#
#      recall_25_tfidf_bm25_no_stemmer  P_10_tfidf_default  map_tfidf_default  \
# 0                           0.000000                 0.0           0.000000
# 1                           0.000000                 0.6           0.538758
# 2                           0.000000                 0.1           0.034496
# 3                           1.000000                 0.0           0.002364
# 4                           0.500000                 0.2           1.000000
# ..                               ...                 ...                ...
# 318                         0.048544                 0.5           0.315086
# 319                         0.000000                 0.1           0.100000
# 320                         0.333333                 0.0           0.071429
# 321                         0.000000                 0.1           0.333333
# 322                         0.000000                 0.0           0.000000
#
#      recall_25_tfidf_default  ndcg_tfidf_default  P_10_bm25_default  \
# 0                   0.000000            0.000000                0.0
# 1                   0.133333            0.195075                0.6
# 2                   0.041667            0.194871                0.1
# 3                   0.000000            0.114575                0.0
# 4                   1.000000            1.000000                0.2
# ..                       ...                 ...                ...
# 318                 0.072816            0.408654                0.6
# 319                 0.333333            0.135652                0.1
# 320                 0.333333            0.120116                0.0
# 321                 0.333333            0.234639                0.1
# 322                 0.000000            0.000000                0.0
#
#      map_bm25_default  recall_25_bm25_default  ndcg_bm25_default
# 0            0.000000                0.000000           0.000000
# 1            0.538758                0.133333           0.195075
# 2            0.033877                0.041667           0.193503
# 3            0.002278                0.000000           0.113878
# 4            1.000000                1.000000           1.000000
# ..                ...                     ...                ...
# 318          0.324810                0.067961           0.412933
# 319          0.100000                0.333333           0.135652
# 320          0.071429                0.333333           0.120116
# 321          0.333333                0.333333           0.234639
# 322          0.000000                0.000000           0.000000
#
# [323 rows x 33 columns]

# %%
# mean df rows
df_mean = pd.DataFrame([df['qid'], df.mean(axis=1, numeric_only = True)])
df_mean = df_mean.T
df_mean.columns = ['qid', 'mean']
df_mean = df_mean.sort_values(ascending = True, by = 'mean')
df_mean.head()
# Out:
#             qid mean
# 0    PLAIN-1008  0.0
# 137  PLAIN-2321  0.0
# 136  PLAIN-2311  0.0
# 132  PLAIN-2281  0.0
# 131  PLAIN-2271  0.0

# %%
df_mean = df_mean.sort_values(ascending = False, by = 'mean')
df_mean.head()
# Out:
#             qid      mean
# 71   PLAIN-1710  0.909126
# 271   PLAIN-488  0.847294
# 295   PLAIN-721  0.835698
# 307   PLAIN-838    0.7967
# 300   PLAIN-771  0.783252
